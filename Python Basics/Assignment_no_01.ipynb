# %% [markdown]
# #### 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.

# %% [markdown]
# `* `
#
# `'hello'`
#
# `-87.8`
#
# `- `
#
# `/`
#
# `+`
#
# `6`

# %% [markdown]
# **Their are 4 operators and 3 expressions**

# %% [markdown]
# **Operators**:`-`,`/`,`+`,`*`

# %% [markdown]
# **Expression**:`hello`,`-87.8`,`6`

# %% [markdown]
# #### 2. What is the difference between string and variable?

# %% [markdown]
# **string:** String is a type of information you would store in a Variable,String is a group of characters or a single character usually enclosed in Double quotes `" "` or single quotes `' '`

# %% [markdown]
# **Variable:**A Variable is used to store of information, and a String is a type of information you would store in a Variable

# %% [markdown]
# #### 3. Describe three different data types.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1)Numeric
#
# 1)Dictionary
#
# 2)Boolean
#
# 3)Set
#
# 4)Sequence Type:
#
# - String
# In Python, Strings are arrays of bytes representing Unicode characters. A string is a collection of one or more characters put in a single quote, double-quote or triple quote. In python there is no character data type, a character is a string of length one. It is represented by str class.
#
#
# - List
# Lists are just like the arrays, declared in other languages which is a ordered collection of data. It is very flexible as the items in a list do not need to be of the same type.
#
#
# - Tuple
# Just like list, tuple is also an ordered collection of Python objects. The only difference between tuple and list is that tuples are immutable i.e. tuples cannot be modified after it is created. It is represented by tuple class.

# %% [markdown]
# #### 4. What is an expression made up of? What do all expressions do?

# %% [markdown]
# An expression is a combination of operators, constants and variables. An expression may consist of one or more operands, and zero or more operators to produce a value

# %% [markdown]
# #### 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [markdown]
#  An expression is a combination of values, variables, and operators.When we type an expression at the prompt,
# the interpreter evaluates it, which means that it finds the value of the expression.
#
# **eg:** 4*5+20-40 is an example of a statement
#
# A statement is a unit of code that has an effect, like creating a variable or displaying a value.When we type a statement,
# the interpreter executes it, which means that it does whatever the statement says. In general, statements don’t have values.
#
# **eg:** variable declaration and assignment are statements because they do not return a value

# %% [markdown]
# #### 6. After running the following code, what does the variable bacon contain?

# %%
bacon = 22
bacon + 1
# Out:
# 23

# %%
bacon = 22 ##  variable name is bacon ,which is storing the number 22

# %%
bacon +1  ## here we are adding 1 to the variable number which is containg the number 22
# Out:
# 23

# %% [markdown]
# we are add the number to the variable which has a value stored as 22
# so we get the number 23

# %% [markdown]
# #### 7. What should the values of the following two terms be?

# %%
'spam' + 'spamspam'
'spam' * 3
# Out:
# 'spamspamspam'

# %%
'spam' + 'spamspam'  # string concatenation
# Out:
# 'spamspamspam'

# %%
'spam' * 3 # string multiplication
# Out:
# 'spamspamspam'

# %% [markdown]
# **Ans:** Both expressions evaluate to the string **`'spamspamspam'`**
# Where as the first expression follows `String Concatentation` and the second expression follows `String Multiplication`

# %% [markdown]
# #### 8. Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# As per python,Variable names cannot begin with a number. The python rules for naming a variable are :-
#
# 1. Variable name must start with a letter or the underscore character.
# 2. Variable name cannot start with a number.
# 3. Variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, & _ ).
# 4. Variable names are case-sensitive (name, `AMERICA` and `america` are three different variables).
# 5. The reserved words(keywords) cannot be used naming the variable.

# %% [markdown]
# #### 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %%
# Examples:
print('int(45) -> ',int(45))            # int() function converts given input to int
print('float(56) -> ',float(56))                # float() function converts given input to float
print('str(45) -> ',str(45))                             # str() function converts given input to string
# Out:
# int(45) ->  45
# float(56) ->  56.0
# str(45) ->  45

# %% [markdown]
# #### 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'

# %% [markdown]
# **Ans:**
# Only Strings datatypes  can be concatenated and so the number 99 is an interger so in order to concate we have to convert it into a string
#  to convert it into a string we have to give the single or double inverted commas
